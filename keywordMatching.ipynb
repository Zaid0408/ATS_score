# %%
import sqlite3
connection = sqlite3.connect("database.db")
cursor = connection.cursor()

# %%
sql_command = """CREATE TABLE emp ( 
sl_no INTEGER PRIMARY KEY, 
dataOfResume VARCHAR);"""

cursor.execute(sql_command)
connection.commit()

# %%
cursor.execute("PRAGMA table_info(emp);")

# Fetch and print the schema information
schema = cursor.fetchall()

for column in schema:
    print(column)
# Out:
# (0, 'sl_no', 'INTEGER', 0, None, 1)
# (1, 'dataOfResume', 'VARCHAR', 0, None, 0)

# %%
keywords = [
    "Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.",
    "Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.",
    "Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.",
    "Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.",
    "Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services."
]

for _ in range(100):
    for keyword in keywords:
        cursor.execute('''
            INSERT INTO emp (dataOfResume)
            VALUES (?);
        ''', (keyword,))

# Commit the transaction
connection.commit()

# %%
cursor.execute('''
    SELECT * FROM emp
    LIMIT 50;
''')

# Fetch all the results
rows = cursor.fetchall()

# Print each row
for row in rows:
    print(row)
# Out:
# (1, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (2, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (3, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (4, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (5, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (6, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (7, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (8, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (9, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (10, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (11, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (12, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (13, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (14, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (15, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (16, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (17, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (18, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (19, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (20, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (21, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (22, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (23, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (24, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (25, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (26, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (27, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (28, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (29, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (30, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (31, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (32, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (33, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (34, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (35, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (36, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (37, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (38, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (39, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (40, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (41, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (42, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (43, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (44, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (45, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (46, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (47, 'Implemented real-time data processing using Apache Kafka and integrated it with a robust data warehousing solution, ensuring seamless data flow and analytics.')
# (48, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (49, 'Designed and developed a distributed caching system using Redis to improve application performance and scalability, while managing session state across multiple servers.')
# (50, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')

# %%
from thefuzz import process,fuzz

# %%
s1="Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs."
s2="Django FastAPI Flutter Orm"
s3="Django FastAPI Django FastAPI FastAPI Django"

print(fuzz.ratio(s1,s2)) # Good for comparing two strings directly, where the sequence and character positions matter.
print(fuzz.partial_ratio(s1,s2)) # Effective when s2 is expected to match part of s1.
print(fuzz.partial_token_set_ratio(s1,s2)) # Best when the comparison needs to focus on content rather than order or duplication.
print(fuzz.partial_token_sort_ratio(s1,s2)) # Effective when the strings have the same words in different orders.
print(fuzz.token_set_ratio(s1,s2)) #Best for cases where you want to ignore word order and duplicates entirely.
print(fuzz.QRatio(s1,s2)) # Used when you want to directly compare two strings.
# Out:
# 23
# 69
# 100
# 62
# 82
# 24

# %%
cursor.execute('SELECT sl_no, dataOfResume FROM emp LIMIT 10;')
rows = cursor.fetchall()

for row in rows:
    entry_id = row[0]
    resume_text = row[1]
    
    # Calculate the similarity score
    similarity_score = fuzz.partial_token_set_ratio(resume_text, s2)
    token_score = fuzz.token_set_ratio(resume_text, s2)
   
    
    # Determine if the keyword is present (threshold can be adjusted)
    if similarity_score >= 80:  # 80 is an arbitrary threshold for a "good" match
        print(f"Entry ID {entry_id} likely contains the keywords  (Score: {similarity_score})")
        print(f"Entry ID {entry_id} likely contains the keywords  but with token set ratio (Score: {token_score})")
        print('\n')
    else:
        print(f"Entry ID {entry_id} does NOT contain the keywords  (Score: {similarity_score})")
        print(f"Entry ID {entry_id} does NOT contains the keywords  but with token set ratio (Score: {token_score})")
        print('\n')
# Out:
# Entry ID 1 likely contains the keywords  (Score: 100)
# Entry ID 1 likely contains the keywords  but with token set ratio (Score: 82)
#
#
# Entry ID 2 does NOT contain the keywords  (Score: 42)
# Entry ID 2 does NOT contains the keywords  but with token set ratio (Score: 23)
#
#
# Entry ID 3 likely contains the keywords  (Score: 100)
# Entry ID 3 likely contains the keywords  but with token set ratio (Score: 70)
#
#
# Entry ID 4 does NOT contain the keywords  (Score: 46)
# Entry ID 4 does NOT contains the keywords  but with token set ratio (Score: 20)
#
#
# Entry ID 5 likely contains the keywords  (Score: 100)
# Entry ID 5 likely contains the keywords  but with token set ratio (Score: 82)
#
#
# Entry ID 6 likely contains the keywords  (Score: 100)
# Entry ID 6 likely contains the keywords  but with token set ratio (Score: 82)
#
#
# Entry ID 7 does NOT contain the keywords  (Score: 42)
# Entry ID 7 does NOT contains the keywords  but with token set ratio (Score: 23)
#
#
# Entry ID 8 likely contains the keywords  (Score: 100)
# Entry ID 8 likely contains the keywords  but with token set ratio (Score: 70)
#
#
# Entry ID 9 does NOT contain the keywords  (Score: 46)
# Entry ID 9 does NOT contains the keywords  but with token set ratio (Score: 20)
#
#
# Entry ID 10 likely contains the keywords  (Score: 100)
# Entry ID 10 likely contains the keywords  but with token set ratio (Score: 82)

# %%
query_like = '''
SELECT sl_no, dataOfResume
FROM emp
WHERE dataOfResume LIKE '%Django%'
  AND dataOfResume LIKE '%FastAPI%'
  AND dataOfResume LIKE '%ORM%';
'''

cursor.execute(query_like)
results = cursor.fetchall()

# Print the results
for row in results:
    print(row)
# Out:
# (1, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (3, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (5, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (6, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (8, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (10, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (11, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (13, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (15, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (16, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (18, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (20, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (21, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (23, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (25, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (26, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (28, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (30, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (31, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (33, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (35, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (36, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (38, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (40, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (41, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (43, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (45, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (46, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (48, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (50, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (51, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (53, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (55, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (56, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (58, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (60, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (61, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (63, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (65, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (66, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (68, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (70, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (71, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (73, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (75, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (76, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (78, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (80, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (81, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (83, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (85, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (86, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (88, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (90, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (91, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (93, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (95, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (96, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (98, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (100, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (101, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (103, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (105, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (106, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (108, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (110, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (111, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (113, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (115, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (116, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (118, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (120, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (121, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (123, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (125, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (126, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (128, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (130, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (131, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (133, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (135, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (136, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (138, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (140, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (141, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (143, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (145, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (146, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (148, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (150, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (151, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (153, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (155, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (156, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (158, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (160, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (161, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (163, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (165, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (166, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (168, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (170, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (171, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (173, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (175, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (176, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (178, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (180, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (181, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (183, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (185, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (186, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (188, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (190, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (191, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (193, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (195, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (196, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (198, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (200, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (201, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (203, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (205, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (206, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (208, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (210, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (211, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (213, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (215, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (216, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (218, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (220, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (221, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (223, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (225, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (226, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (228, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (230, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (231, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (233, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (235, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (236, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (238, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (240, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (241, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (243, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (245, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (246, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (248, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (250, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (251, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (253, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (255, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (256, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (258, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (260, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (261, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (263, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (265, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (266, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (268, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (270, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (271, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (273, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (275, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (276, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (278, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (280, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (281, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (283, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (285, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (286, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (288, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (290, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (291, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (293, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (295, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (296, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (298, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (300, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (301, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (303, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (305, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (306, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (308, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (310, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (311, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (313, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (315, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (316, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (318, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (320, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (321, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (323, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (325, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (326, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (328, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (330, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (331, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (333, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (335, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (336, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (338, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (340, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (341, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (343, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (345, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (346, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (348, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (350, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (351, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (353, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (355, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (356, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (358, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (360, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (361, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (363, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (365, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (366, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (368, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (370, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (371, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (373, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (375, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (376, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (378, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (380, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (381, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (383, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (385, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (386, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (388, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (390, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (391, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (393, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (395, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (396, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (398, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (400, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (401, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (403, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (405, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (406, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (408, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (410, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (411, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (413, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (415, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (416, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (418, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (420, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (421, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (423, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (425, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (426, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (428, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (430, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (431, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (433, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (435, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (436, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (438, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (440, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (441, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (443, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (445, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (446, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (448, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (450, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (451, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (453, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (455, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (456, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (458, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (460, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (461, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (463, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (465, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (466, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (468, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (470, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (471, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (473, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (475, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (476, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (478, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (480, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (481, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (483, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (485, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (486, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (488, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (490, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (491, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (493, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (495, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')
# (496, 'Developed and maintained web applications using Django and FastAPI, leveraging Django ORM models for efficient database management and FastAPI for building high-performance APIs.')
# (498, 'Designed a microservices architecture with Django and FastAPI, where Django managed the core application logic and FastAPI handled the asynchronous API requests, improving overall system performance.')
# (500, 'Engineered RESTful APIs using FastAPI, optimizing asynchronous tasks and integrating with Django’s powerful ORM for consistent data handling across services.')

# %%
# Delete the table
cursor.execute('DROP TABLE emp;')
connection.commit()

# %%
import os
# To delete database

db_path = '/Users/sherazhasan/Desktop/test3/scripts-archive/database.db'

# Remove the database file
if os.path.exists(db_path):
    os.remove(db_path)
    print(f"Database '{db_path}' deleted successfully.")
else:
    print(f"Database '{db_path}' does not exist.")
# Out:
# Database '/Users/sherazhasan/Desktop/test3/scripts-archive/database.db' deleted successfully.
